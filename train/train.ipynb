# %%
from ultralytics import YOLO

# %%
# Load the model.
model = YOLO('yolov8n.pt')

# %%
# dataset/
# ├── images/
# │   ├── train/
# │   └── val/
# ├── labels/
# │   ├── train/
# │   └── val/
# └── custom_data.yaml

# %%
# 1. read all images and labels pathes
# 2. Create a pull from that list
# 3. Devide images equally with classes label by 80/20 train/val

# %%
# Training.
results = model.train(
    data='train/dataset/custom_data.yaml',
    imgsz=640,
    epochs=10,
    batch=8,
    name='yolov8n_custom')
# Out:
# Ultralytics 8.3.246 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1060, 6063MiB)
# ...
